# %% [markdown]
# # Import all data

# %%
import pandas as pd

# %% [markdown]
# ## PC6 levels

# %%
# PC6 general
data_PC6 = pd.read_csv(r'path\to\file\data_PC6.csv', sep=',', index_col=0)

# %%
# Land Use
data_landuse = pd.read_csv(r'path\to\file\data_land_use_by_postcode.csv', sep=',')

# %% [markdown]
# Strandeiland and Buiteneiland are new islands, in construction, so nothing recorded yet but the land use.

# %%
# Transportation
data_bus = pd.read_csv(r'path\to\file\data_bus_by_postcode.csv', sep=',')
data_tram_metro = pd.read_csv(r'path\to\file\data_public_transport_by_postcode.csv', sep=',')

# %%
# Parking 
data_parking = pd.read_csv(r'path\to\file\data_parking_by_postcode.csv', sep=',')

# %%
from functools import reduce

# Define list of all DataFrames of level PC6
level_PC6 = [data_PC6, data_bus, data_tram_metro, data_parking, data_landuse]

# Merge all DataFrames into one
data_level_PC6 = reduce(lambda  left,right: pd.merge(left, right, on='PC6',
                                                     how='outer'), level_PC6)

# Fill NAs where neccesary
columns_to_fillna = ['bus_count','metro_count','tram_count','parking_count']
data_level_PC6[columns_to_fillna] = data_level_PC6[columns_to_fillna].fillna(0)

# %%
# Get PC4 level for merging later
data_level_PC6['PC4'] = data_level_PC6['PC6'].str[:4].astype(float)

# %%
data_level_PC6.head()
# Out:
#       PC6  bus_count  metro_count  tram_count  parking_count  traffic_area  \
# 0  1011AB        0.0          0.0         0.0            0.0        5.5393
# 1  1011AC        0.0          0.0         1.0            0.0        5.5393
# 2  1011AG        0.0          0.0         0.0            0.0        0.4505
# 3  1011AH        0.0          0.0         0.0            0.0        0.4505
# 4  1011AJ        0.0          0.0         0.0            0.0        0.4505
#
#    built_up_area  semi_built_up_area  recreational_area  agrarian_area  \
# 0         5.3554              1.4589                0.0            0.0
# 1         5.3554              1.4589                0.0            0.0
# 2         4.8640              0.0000                0.0            0.0
# 3         4.8640              0.0000                0.0            0.0
# 4         4.8640              0.0000                0.0            0.0
#
#    forest_nature_are  water_body_area     PC4
# 0                0.0          11.9398  1011.0
# 1                0.0          11.9398  1011.0
# 2                0.0           2.4582  1011.0
# 3                0.0           2.4582  1011.0
# 4                0.0           2.4582  1011.0

# %% [markdown]
# ## PC4 levels

# %%
import numpy as np

# Registered EVs vehicles
data_ev = pd.read_csv(r'path\to\file\ev_ams_passenger.csv', sep=',')
data_ev = data_ev[['PC4','December 2022_EV']]

# Replace cells in the December 2022_EV column with NaN based on the outlier postcode
data_ev.loc[data_ev['PC4'] == 1097, 'December 2022_EV'] = np.nan
data_ev.loc[data_ev['PC4'] == 1082, 'December 2022_EV'] = np.nan
data_ev.loc[data_ev['PC4'] == 1101, 'December 2022_EV'] = np.nan
data_ev.loc[data_ev['PC4'] == 1102, 'December 2022_EV'] = np.nan
data_ev.head()
# Out:
#     PC4  December 2022_EV
# 0  1011             367.0
# 1  1012              79.0
# 2  1013             228.0
# 3  1014             363.0
# 4  1015             116.0

# %%
# Registered hybrid vehicles
data_hybrid = pd.read_csv(r'path\to\file\hybird_ams_passenger.csv', sep=',')
data_hybrid = data_hybrid[['PC4','December 2022_hybrid']]

# Replace cells in the December 2022_EV column with NaN based on the outlier postcode
data_hybrid.loc[data_hybrid['PC4'] == 1012, 'December 2022_hybrid'] = np.nan
data_hybrid.loc[data_hybrid['PC4'] == 1071, 'December 2022_hybrid'] = np.nan
data_hybrid.loc[data_hybrid['PC4'] == 1077, 'December 2022_hybrid'] = np.nan
data_hybrid.loc[data_hybrid['PC4'] == 1102, 'December 2022_hybrid'] = np.nan
data_hybrid.head()
# Out:
#     PC4  December 2022_hybrid
# 0  1011                 187.0
# 1  1012                   NaN
# 2  1013                 154.0
# 3  1014                  82.0
# 4  1015                 109.0

# %%
# Population
data_population_age = pd.read_csv(r'path\to\file\data_population_age.csv', sep=',')
data_population_age = data_population_age[['PC4','2022_0_to_10','2022_10_to_20','2022_20_to_30','2022_30_to_40','2022_40_to_50']]
data_population_age.head()
# Out:
#     PC4  2022_0_to_10  2022_10_to_20  2022_20_to_30  2022_30_to_40  \
# 0  1011         475.0          540.0         2065.0         1645.0
# 1  1012         280.0          330.0         3120.0         2045.0
# 2  1013        1600.0         1670.0         3805.0         4000.0
# 3  1014         625.0          245.0          395.0          945.0
# 4  1015         815.0          925.0         2920.0         2630.0
#
#    2022_40_to_50
# 0         1080.0
# 1         1010.0
# 2         2920.0
# 3          610.0
# 4         1825.0

# %%
# Household
data_household = pd.read_csv(r'path\to\file\data_household.csv', sep=',')
data_household = data_household[['PC4','2019.0_household']]
data_household.head()
# Out:
#       PC4  2019.0_household
# 0  1011.0              6200
# 1  1012.0              5700
# 2  1013.0             12300
# 3  1014.0               900
# 4  1015.0              9400

# %%
# Income
data_income = pd.read_csv(r'path\to\file\data_income_by_postcode.csv', sep=',')
data_income = data_income[['PC4','2019.0_income_1_to_40_percent','2019.0_income_41_to_80_percent','2019.0_income_81_to_100_percent','2019.0_income_average']]
data_income.head()
# Out:
#       PC4  2019.0_income_1_to_40_percent  2019.0_income_41_to_80_percent  \
# 0  1011.0                           45.0                            28.0
# 1  1012.0                           47.1                            29.8
# 2  1013.0                           46.4                            29.4
# 3  1014.0                           24.8                            22.7
# 4  1015.0                           44.4                            27.9
#
#    2019.0_income_81_to_100_percent  2019.0_income_average
# 0                             27.1                   49.3
# 1                             23.1                   46.2
# 2                             24.2                   48.1
# 3                             52.5                   66.6
# 4                             27.7                   50.1

# %%
# Assets
data_assets = pd.read_csv(r'path\to\file\data_asset_by_postcode.csv', sep=',')
data_assets = data_assets[['PC4','2019.0_assets_1_to_40_percent','2019.0_assets_41_to_80_percent','2019.0_assets_81_to_100_percent','2019.0_assets_average']]
data_assets.head()
# Out:
#       PC4  2019.0_assets_1_to_40_percent  2019.0_assets_41_to_80_percent  \
# 0  1011.0                           50.8                            23.0
# 1  1012.0                           63.1                            20.5
# 2  1013.0                           54.7                            25.2
# 3  1014.0                           46.7                            27.4
# 4  1015.0                           50.2                            23.3
#
#    2019.0_assets_81_to_100_percent  2019.0_assets_average
# 0                             26.2                   47.6
# 1                             16.4                   38.2
# 2                             20.1                   44.2
# 3                             25.9                   49.2
# 4                             26.5                   48.3

# %%
# SES
data_ses = pd.read_csv(r'path\to\file\data_ses_woa_by_postcode.csv', sep=',')
data_ses = data_ses[['PC4','2019.0_Gemiddelde SES WOA totaalscore']]
data_ses.head()
# Out:
#       PC4  2019.0_Gemiddelde SES WOA totaalscore
# 0  1011.0                                  0.034
# 1  1012.0                                  0.010
# 2  1013.0                                 -0.033
# 3  1014.0                                  0.321
# 4  1015.0                                  0.038

# %%
# Define list of all DataFrames of level PC4
level_PC4 = [data_ev, data_hybrid, data_population_age, data_household, data_income, data_assets, data_ses]

# Merge all DataFrames into one
data_level_PC4 = reduce(lambda  left,right: pd.merge(left, right, on='PC4',
                                                     how='outer'), level_PC4)

# Fill NAs where neccesary
data_level_PC4.iloc[:, 3:] = data_level_PC4.iloc[:, 3:].fillna(0)

# %%
data_level_PC4.head()
# Out:
#     PC4  December 2022_EV  December 2022_hybrid  2022_0_to_10  2022_10_to_20  \
# 0  1011             367.0                 187.0         475.0          540.0
# 1  1012              79.0                   NaN         280.0          330.0
# 2  1013             228.0                 154.0        1600.0         1670.0
# 3  1014             363.0                  82.0         625.0          245.0
# 4  1015             116.0                 109.0         815.0          925.0
#
#    2022_20_to_30  2022_30_to_40  2022_40_to_50  2019.0_household  \
# 0         2065.0         1645.0         1080.0            6200.0
# 1         3120.0         2045.0         1010.0            5700.0
# 2         3805.0         4000.0         2920.0           12300.0
# 3          395.0          945.0          610.0             900.0
# 4         2920.0         2630.0         1825.0            9400.0
#
#    2019.0_income_1_to_40_percent  2019.0_income_41_to_80_percent  \
# 0                           45.0                            28.0
# 1                           47.1                            29.8
# 2                           46.4                            29.4
# 3                           24.8                            22.7
# 4                           44.4                            27.9
#
#    2019.0_income_81_to_100_percent  2019.0_income_average  \
# 0                             27.1                   49.3
# 1                             23.1                   46.2
# 2                             24.2                   48.1
# 3                             52.5                   66.6
# 4                             27.7                   50.1
#
#    2019.0_assets_1_to_40_percent  2019.0_assets_41_to_80_percent  \
# 0                           50.8                            23.0
# 1                           63.1                            20.5
# 2                           54.7                            25.2
# 3                           46.7                            27.4
# 4                           50.2                            23.3
#
#    2019.0_assets_81_to_100_percent  2019.0_assets_average  \
# 0                             26.2                   47.6
# 1                             16.4                   38.2
# 2                             20.1                   44.2
# 3                             25.9                   49.2
# 4                             26.5                   48.3
#
#    2019.0_Gemiddelde SES WOA totaalscore
# 0                                  0.034
# 1                                  0.010
# 2                                 -0.033
# 3                                  0.321
# 4                                  0.038

# %% [markdown]
# # Merge PC4 and PC6

# %%
# Merging all the independent variables
data_independent = data_level_PC6.merge(data_level_PC4, on='PC4', how='left').drop(columns='PC4')

# %%
# Imputate the missing values and abnormalies. We can do this before merging with the target variables as these indepdent features have no time variance to them. 
# We decided to choost the most recent value for all features, as we only have data of the target variables for 2022 and 2023
import miceforest as mf

# Convert object columns to categorical and numeric type 
data_independent['PC6'] = data_independent['PC6'].astype('category')


# Create kernel. 
kds = mf.ImputationKernel(
  data_independent,
  save_all_iterations=True,
  random_state=1991
)

# Run the MICE algorithm for 2 iterations
kds.mice(5)

# Return the completed dataset 
data_independent_complete = kds.complete_data()
# Out:
# c:\Users\vongu\anaconda3\lib\site-packages\miceforest\ImputationKernel.py:371: UserWarning: [PC6] have very rare categories, it is a good idea to group these, or set the min_data_in_leaf parameter to prevent lightgbm from outputting 0.0 probabilities.
#   warn(

# %%
data_independent_complete.head()
# Out:
#       PC6  bus_count  metro_count  tram_count  parking_count  traffic_area  \
# 0  1011AB        0.0          0.0         0.0            0.0        5.5393
# 1  1011AC        0.0          0.0         1.0            0.0        5.5393
# 2  1011AG        0.0          0.0         0.0            0.0        0.4505
# 3  1011AH        0.0          0.0         0.0            0.0        0.4505
# 4  1011AJ        0.0          0.0         0.0            0.0        0.4505
#
#    built_up_area  semi_built_up_area  recreational_area  agrarian_area  ...  \
# 0         5.3554              1.4589                0.0            0.0  ...
# 1         5.3554              1.4589                0.0            0.0  ...
# 2         4.8640              0.0000                0.0            0.0  ...
# 3         4.8640              0.0000                0.0            0.0  ...
# 4         4.8640              0.0000                0.0            0.0  ...
#
#    2019.0_household  2019.0_income_1_to_40_percent  \
# 0            6200.0                           45.0
# 1            6200.0                           45.0
# 2            6200.0                           45.0
# 3            6200.0                           45.0
# 4            6200.0                           45.0
#
#    2019.0_income_41_to_80_percent  2019.0_income_81_to_100_percent  \
# 0                            28.0                             27.1
# 1                            28.0                             27.1
# 2                            28.0                             27.1
# 3                            28.0                             27.1
# 4                            28.0                             27.1
#
#    2019.0_income_average  2019.0_assets_1_to_40_percent  \
# 0                   49.3                           50.8
# 1                   49.3                           50.8
# 2                   49.3                           50.8
# 3                   49.3                           50.8
# 4                   49.3                           50.8
#
#    2019.0_assets_41_to_80_percent  2019.0_assets_81_to_100_percent  \
# 0                            23.0                             26.2
# 1                            23.0                             26.2
# 2                            23.0                             26.2
# 3                            23.0                             26.2
# 4                            23.0                             26.2
#
#    2019.0_assets_average  2019.0_Gemiddelde SES WOA totaalscore
# 0                   47.6                                  0.034
# 1                   47.6                                  0.034
# 2                   47.6                                  0.034
# 3                   47.6                                  0.034
# 4                   47.6                                  0.034
#
# [5 rows x 29 columns]

# %%
#data_independent_complete.to_csv('data_independent_complete.csv', index=True)

# %% [markdown]
# # Merge with the Session Data

# %%
# Read in the session data for target variables
data_session = pd.read_csv(r'path\to\file\df_weekly_22_23.csv', sep=',')
# Out:
# C:\Users\vongu\AppData\Local\Temp\ipykernel_24252\587958277.py:2: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_session = pd.read_csv(r'C:\Users\vongu\UM\Master\Smart Service Project\Registered EVs\df_weekly_22_23.csv', sep=',')

# %%
# Format the columns
data_session = data_session.drop(columns=['City']).rename(columns={'zipcode':'PC6'})
data_session['PC6'] = data_session['PC6'].str.replace(' ', '')

# %%
# Convert 'Date' column to datetime
data_session['Date'] = pd.to_datetime(data_session['Date'])

# Order the data by date and postcode
data_session = data_session.sort_values(by=['Date', 'PC6'], ascending=[True, True])

# %%
data_session.head()
# Out:
#        Unnamed: 0     PC6       Date District  ConnectionTimeHours    kWh  \
# 0               0  1011AB 2022-01-03  Centrum                67.59  125.8
# 66             66  1011AC 2022-01-03        0                 0.00    0.0
# 18084       18084  1011AD 2022-01-03        0                 0.00    0.0
# 18150       18150  1011AE 2022-01-03        0                 0.00    0.0
# 132           132  1011AG 2022-01-03        0                 0.00    0.0
#
#        effective_charging_hrs  power  MaxOccupancy  MaxPower  ...  \
# 0                   22.789855  33.12         288.0   1589.76  ...
# 66                   0.000000   0.00           0.0      0.00  ...
# 18084                0.000000   0.00           0.0      0.00  ...
# 18150                0.000000   0.00           0.0      0.00  ...
# 132                  0.000000   0.00           0.0      0.00  ...
#
#        effective_charging_hrs20-21  effective_charging_hrs21-22  \
# 0                         1.533333                          2.0
# 66                        0.000000                          0.0
# 18084                     0.000000                          0.0
# 18150                     0.000000                          0.0
# 132                       0.000000                          0.0
#
#        effective_charging_hrs22-23  effective_charging_hrs23-24  \
# 0                              2.0                     1.966667
# 66                             0.0                     0.000000
# 18084                          0.0                     0.000000
# 18150                          0.0                     0.000000
# 132                            0.0                     0.000000
#
#        SpareCap_Effective  SpareCap_Occup_kWh  SpareCap_Hrs  Effective%  \
# 0                 1463.96           -648.8208        220.41    0.079131
# 66                   0.00              0.0000          0.00    0.000000
# 18084                0.00              0.0000          0.00    0.000000
# 18150                0.00              0.0000          0.00    0.000000
# 132                  0.00              0.0000          0.00    0.000000
#
#        Occupancy_kwh%  index
# 0            1.408125      1
# 66           0.000000      1
# 18084        0.000000      1
# 18150        0.000000      1
# 132          0.000000      1
#
# [5 rows x 77 columns]

# %% [markdown]
# ## Final Data

# %%
# Merge the target variable with the independent variables
final_data = data_session.merge(data_independent_complete, on='PC6')

# %%
# Order the data by date and postcode
final_data = final_data.sort_values(by=['Date', 'PC6'], ascending=[True, True])

# %%
final_data.head()
# Out:
#      Unnamed: 0     PC6       Date District  ConnectionTimeHours    kWh  \
# 0             0  1011AB 2022-01-03  Centrum                67.59  125.8
# 66           66  1011AC 2022-01-03        0                 0.00    0.0
# 132       18084  1011AD 2022-01-03        0                 0.00    0.0
# 198       18150  1011AE 2022-01-03        0                 0.00    0.0
# 264         132  1011AG 2022-01-03        0                 0.00    0.0
#
#      effective_charging_hrs  power  MaxOccupancy  MaxPower  ...  \
# 0                 22.789855  33.12         288.0   1589.76  ...
# 66                 0.000000   0.00           0.0      0.00  ...
# 132                0.000000   0.00           0.0      0.00  ...
# 198                0.000000   0.00           0.0      0.00  ...
# 264                0.000000   0.00           0.0      0.00  ...
#
#      2019.0_household  2019.0_income_1_to_40_percent  \
# 0              6200.0                           45.0
# 66             6200.0                           45.0
# 132            6200.0                           45.0
# 198            6200.0                           45.0
# 264            6200.0                           45.0
#
#      2019.0_income_41_to_80_percent  2019.0_income_81_to_100_percent  \
# 0                              28.0                             27.1
# 66                             28.0                             27.1
# 132                            28.0                             27.1
# 198                            28.0                             27.1
# 264                            28.0                             27.1
#
#      2019.0_income_average  2019.0_assets_1_to_40_percent  \
# 0                     49.3                           50.8
# 66                    49.3                           50.8
# 132                   49.3                           50.8
# 198                   49.3                           50.8
# 264                   49.3                           50.8
#
#      2019.0_assets_41_to_80_percent  2019.0_assets_81_to_100_percent  \
# 0                              23.0                             26.2
# 66                             23.0                             26.2
# 132                            23.0                             26.2
# 198                            23.0                             26.2
# 264                            23.0                             26.2
#
#      2019.0_assets_average  2019.0_Gemiddelde SES WOA totaalscore
# 0                     47.6                                  0.034
# 66                    47.6                                  0.034
# 132                   47.6                                  0.034
# 198                   47.6                                  0.034
# 264                   47.6                                  0.034
#
# [5 rows x 105 columns]

# %%
#final_data.to_csv('final_data.csv', index=True)
